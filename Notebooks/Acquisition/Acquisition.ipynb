# %%
import pandas as pd
import requests
import numpy as np
import os

# %%
def acquire_catolicos():
    df1 = pd.read_csv("../../data/209426-0-templos-catolicas.csv", delimiter = ";")
    return df1

# %%
def acquire_no_catolicos():
    df2 = pd.read_csv("../../data/209434-0-templos-otros.csv", delimiter = ";")
    return df2

# %%
def acquire_bicimad():
    df3 = pd.read_json("../../data/bicimad_stations.json")
    df3 ['LATITUD'] = [float(index.split(',')[1].replace("]", "")) for index in df3['geometry_coordinates']]
    df3 ['LONGITUD'] = [float(index.split(',')[0].replace("[", "")) for index in df3['geometry_coordinates']]
    return df3

# %%
acquire_catolicos()
# Out:
#            PK                                             NOMBRE  \
# 0        3557                       Basílica Jesús de Medinaceli
# 1        3394                              Basílica La Milagrosa
# 2        3371                  Basílica Pontificia de San Miguel
# 3    11242837                              Capilla de San Isidro
# 4        3361        Catedral Santa María la Real de la Almudena
# ..        ...                                                ...
# 382     60234           Santuario Nuestra Señora de los Peligros
# 383      3737                Santuario Nuestra Señora de Lourdes
# 384    190382             Santuario Nuestra Señora de Schönstatt
# 385     60225  Segundo Monasterio de la Visitación (Las Salesas)
# 386     60226   Tercer Monasterio de la Visitación (Las Salesas)
#
#                                    DESCRIPCION-ENTIDAD  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    Su construcción comienza a finales del siglo X...
# ..                                                 ...
# 382                                                NaN
# 383                                                NaN
# 384                                                NaN
# 385                                                NaN
# 386                                                NaN
#
#                                                HORARIO EQUIPAMIENTO  \
# 0                                                  NaN          NaN
# 1                                                  NaN          NaN
# 2                                                  NaN          NaN
# 3    Día 4 de cada mes (si coincide con un sábado, ...          NaN
# 4                                                  NaN          NaN
# ..                                                 ...          ...
# 382                                                NaN          NaN
# 383                                                NaN          NaN
# 384                                                NaN          NaN
# 385                                                NaN          NaN
# 386                                                NaN          NaN
#
#                                             TRANSPORTE  \
# 0    Metro: Antón Martín (línea 1).   Bus: 001, 10,...
# 1    Metro: Alonso Cano (línea 7), Gregorio Marañón...
# 2    Metro: Sol (líneas 1, 2 y 3), Tirso de Molina ...
# 3    Metro: La Latina (línea 5), Puerta de Toledo (...
# 4    Metro: Ópera (líneas 2, 5 y Ramal), Sol (Línea...
# ..                                                 ...
# 382  Bus: C2, C1, 16, 19, 51.   Metro: República Ar...
# 383  Metro: Rubén Darío (línea 5), Alonso Martínez ...
# 384  Metro: Gregorio Marañón (líneas 7 y 10).    Bu...
# 385  Metro: San Bernardo (líneas 2 y 4).  Bus: 147,...
# 386  Metro: Guzmán el Bueno (líneas 6 y 7).  Bus: 4...
#
#                                            DESCRIPCION  ACCESIBILIDAD  \
# 0                                                  NaN              3
# 1                                                  NaN              3
# 2                                                  NaN              3
# 3    Descripción monumental: el Oratorio está ubica...              1
# 4                                                  NaN              3
# ..                                                 ...            ...
# 382                                                NaN              3
# 383                                                NaN              3
# 384                                                NaN              3
# 385                                                NaN              3
# 386                                                NaN              3
#
#                                            CONTENT-URL  \
# 0    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 1    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 2    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 3    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 4    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# ..                                                 ...
# 382  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 383  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 384  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 385  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 386  http://www.madrid.es/sites/v/index.jsp?vgnextc...
#
#                  NOMBRE-VIA  ...   DISTRITO COORDENADA-X  COORDENADA-Y  \
# 0                     JESUS  ...     CENTRO       440983       4473944
# 1         GARCIA DE PAREDES  ...   CHAMBERI       440994       4476465
# 2                 SAN JUSTO  ...     CENTRO       439790       4473973
# 3                    AGUILA  ...     CENTRO       439593       4473511
# 4                    BAILEN  ...     CENTRO       439452       4474125
# ..                      ...  ...        ...          ...           ...
# 382           JOAQUIN COSTA  ...  CHAMARTIN       442149       4477068
# 383                 FORTUNY  ...   CHAMBERI       441391       4475735
# 384                 SERRANO  ...  CHAMARTIN       441781       4476632
# 385            SAN BERNARDO  ...     CENTRO       440096       4475443
# 386  SAN FRANCISCO DE SALES  ...   CHAMBERI       439725       4477237
#
#        LATITUD  LONGITUD                    TELEFONO FAX  \
# 0    40.414018 -3.695608  914 299 375 /  914 296 893 NaN
# 1    40.436738 -3.695725   914 473 248 / 914 473 249 NaN
# 2    40.414203 -3.709672                 915 484 011 NaN
# 3    40.410035 -3.711938   913 650 841 / 913 652 160 NaN
# 4    40.415548 -3.713670                 915 422 200 NaN
# ..         ...       ...                         ...  ..
# 382  40.442252 -3.682151                 915 613 241 NaN
# 383  40.430190 -3.690965                 913 197 780 NaN
# 384  40.438298 -3.686450                 915 618 992 NaN
# 385  40.427468 -3.706204                 915 222 565 NaN
# 386  40.443602 -3.710745                 915 985 575 NaN
#
#                                            EMAIL  \
# 0                 jesusmedinaceli@archimadrid.es
# 1              parroquiamilagrosa@archimadrid.es
# 2                                 info@miguel.es
# 3                 info@cementeriodesanisidro.com
# 4            informacion@catedraldelaalmudena.es
# ..                                           ...
# 382                                          NaN
# 383                                          NaN
# 384                                          NaN
# 385                                          NaN
# 386  c.inmaculadaconcepcionmadrid@servidoras.org
#
#                                                   TIPO  Unnamed: 30
# 0    /contenido/entidadesYorganismos/TemplosIglesia...
# 1    /contenido/entidadesYorganismos/TemplosIglesia...
# 2    /contenido/entidadesYorganismos/MonumentosEdif...
# 3    /contenido/entidadesYorganismos/MonumentosEdif...
# 4    /contenido/entidadesYorganismos/MonumentosEdif...
# ..                                                 ...          ...
# 382  /contenido/entidadesYorganismos/TemplosIglesia...
# 383  /contenido/entidadesYorganismos/TemplosIglesia...
# 384  /contenido/entidadesYorganismos/TemplosIglesia...
# 385  /contenido/entidadesYorganismos/TemplosIglesia...
# 386  /contenido/entidadesYorganismos/TemplosIglesia...          NaN
#
# [387 rows x 31 columns]

# %%
acquire_no_catolicos()
# Out:
#            PK                                             NOMBRE  \
# 0    11025958  Asambleas de Evangelización Mundial para Crist...
# 1     4530770  Asociación Darse - Dar Ayuda para la Reinserci...
# 2    11431772                      Asociación Tiempo Para Cuidar
# 3    11431776                    Asociación Visión Internacional
# 4    11026233  Casa sobre la Roca Iglesia Cristiana Integral ...
# ..        ...                                                ...
# 142    189410  Testigos Cristianos de Jehová. Calle Puerto de...
# 143    189966    Testigos Cristianos de Jehová. Calle San Moisés
# 144  11432588     Testigos Cristianos de Jehová. Calle Tembleque
# 145    189351  Testigos Cristianos de Jehová. Calle Venancio ...
# 146  11431642                  Unión De Mujeres Evangélicas UDME
#
#     DESCRIPCION-ENTIDAD  HORARIO     EQUIPAMIENTO  \
# 0     Templo evangélico      NaN              NaN
# 1                   NaN      NaN              NaN
# 2     Templo evangélico      NaN              NaN
# 3     Templo evangélico      NaN              NaN
# 4     Templo evangélico      NaN              NaN
# ..                  ...      ...              ...
# 142                 NaN      NaN  Tres auditorios
# 143                 NaN      NaN              NaN
# 144                 NaN      NaN              NaN
# 145                 NaN      NaN              NaN
# 146   Templo evangélico      NaN              NaN
#
#                                             TRANSPORTE  \
# 0    Metro: San Francisco (línea 11)  Bus: 108, 118...
# 1       Metro 5(calle Camino Viejo de Leganés 1):urgel
# 2    Metro: Palos de la Frontera (línea 3)  Bus:  1...
# 3           Metro: Torre Arias (línea 5)  Bus:  28, 48
# 4    Metro: Arturo Soria (línea 4)  Bus: 120, 122, ...
# ..                                                 ...
# 142  Bus: 130, T31    Renfe: Vallecas (C2)    Metro...
# 143  Bus: 57, 103, 111, 144  Renfe: Asamblea de Mad...
# 144  Metro: Empalme, Campamento (línea 4)  Bus: 25,...
# 145  Metro: Nueva Numancia (línea 1)  Bus: 141  Bic...
# 146  Metro: Alfonso XIII  (línea 4)  Bus: 120, 43, ...
#
#                                            DESCRIPCION  ACCESIBILIDAD  \
# 0                                                  NaN              3
# 1    Entidad inscrita en el Censo Municipal de Enti...              0
# 2                                                  NaN              3
# 3                                                  NaN              3
# 4                                                  NaN              3
# ..                                                 ...            ...
# 142                                                NaN              3
# 143                                                NaN              3
# 144                                                NaN              3
# 145                                                NaN              3
# 146                                                NaN              3
#
#                                            CONTENT-URL  \
# 0    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 1    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 2    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 3    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 4    http://www.madrid.es/sites/v/index.jsp?vgnextc...
# ..                                                 ...
# 142  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 143  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 144  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 145  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 146  http://www.madrid.es/sites/v/index.jsp?vgnextc...
#
#                       NOMBRE-VIA  ...             DISTRITO COORDENADA-X  \
# 0    ANTONIA RODRIGUEZ SACRISTAN  ...          CARABANCHEL     436747.0
# 1             ALTO DE SAN ISIDRO  ...          CARABANCHEL     438658.0
# 2                   GENERAL LACY  ...           ARGANZUELA     441369.0
# 3                      DISCOBOLO  ...  SAN BLAS-CANILLEJAS     448015.0
# 4                         ULISES  ...        CIUDAD LINEAL     444411.0
# ..                           ...  ...                  ...          ...
# 142            PUERTO DE POZAZAL  ...    VILLA DE VALLECAS     446712.0
# 143                   SAN MOISÉS  ...   PUENTE DE VALLECAS     443504.0
# 144                    TEMBLEQUE  ...               LATINA     435476.0
# 145              VENANCIO MARTIN  ...   PUENTE DE VALLECAS     443866.0
# 146              GABRIEL Y GALAN  ...            CHAMARTIN     443219.0
#
#      COORDENADA-Y    LATITUD  LONGITUD   TELEFONO  FAX               EMAIL  \
# 0       4469402.0  40.372800 -3.745074        NaN  NaN                 NaN
# 1       4472013.0  40.396470 -3.722813  676247792  NaN  darseorg@gmail.com
# 2       4472742.0  40.403234 -3.690948        NaN  NaN                 NaN
# 3       4477077.0  40.442728 -3.612983        NaN  NaN                 NaN
# 4       4478618.0  40.456372 -3.655613        NaN  NaN                 NaN
# ..            ...        ...       ...        ...  ...                 ...
# 142     4470267.0  40.379417 -3.629058        NaN  NaN                 NaN
# 143     4470379.0  40.382078 -3.665580        NaN  NaN                 NaN
# 144     4471898.0  40.395189 -3.760301        NaN  NaN                 NaN
# 145     4472138.0  40.397957 -3.661471        NaN  NaN                 NaN
# 146     4478101.0  40.451635 -3.669618        NaN  NaN                 NaN
#
#                                                   TIPO  Unnamed: 30
# 0    /contenido/entidadesYorganismos/TemplosOtrasRe...
# 1    /contenido/entidadesYorganismos/TemplosOtrasRe...
# 2    /contenido/entidadesYorganismos/TemplosOtrasRe...
# 3    /contenido/entidadesYorganismos/TemplosOtrasRe...
# 4    /contenido/entidadesYorganismos/TemplosOtrasRe...
# ..                                                 ...          ...
# 142  /contenido/entidadesYorganismos/TemplosOtrasRe...
# 143  /contenido/entidadesYorganismos/TemplosOtrasRe...
# 144  /contenido/entidadesYorganismos/TemplosOtrasRe...
# 145  /contenido/entidadesYorganismos/TemplosOtrasRe...
# 146  /contenido/entidadesYorganismos/TemplosOtrasRe...          NaN
#
# [147 rows x 31 columns]

# %%
acquire_bicimad()
# Out:
#       id                    name  light number  \
# 0      1        Puerta del Sol A      2     1a
# 1      2        Puerta del Sol B      1     1b
# 2      3             Miguel Moya      2      2
# 3      4      Plaza Conde Suchil      0      3
# 4      5                Malasaña      2      4
# ..   ...                     ...    ...    ...
# 259  266  Ciudad Universitaria 1      0    258
# 260  267  Ciudad Universitaria 2      2    259
# 261  268       Facultad Biología      2    260
# 262  269        Facultad Derecho      0    261
# 263  270                 Zurbano      0    247
#
#                                                address  activate  \
# 0                                  Puerta del Sol nº 1         1
# 1                                  Puerta del Sol nº 1         1
# 2                               Calle Miguel Moya nº 1         1
# 3             Plaza del Conde del Valle de Súchil nº 3         1
# 4                          Calle Manuela Malasaña nº 5         1
# ..                                                 ...       ...
# 259  Avenida de la Complutense (Metro Ciudad Univer...         1
# 260  Avenida de la Complutense (Metro Ciudad Univer...         1
# 261          Calle José Antonio Novais frente al nº 12         1
# 262                          Avenida Complutense nº 23         1
# 263                                Calle Zurbano nº 90         1
#
#      no_available  total_bases  dock_bikes  free_bases  reservations_count  \
# 0               0           30          15          11                   0
# 1               0           30          22           4                   0
# 2               0           24          12          11                   0
# 3               0           18           4          11                   0
# 4               0           24          12          12                   0
# ..            ...          ...         ...         ...                 ...
# 259             0           24           0          24                   0
# 260             0           24          12          12                   0
# 261             0           24           9          14                   0
# 262             0           24           5          18                   0
# 263             0           24           6          15                   0
#
#     geometry_type                     geometry_coordinates  LONGITUD  \
# 0           Point                 [-3.7018341, 40.4172137] -3.701834
# 1           Point  [-3.701602938060457, 40.41731271011562] -3.701603
# 2           Point                 [-3.7058415, 40.4205886] -3.705842
# 3           Point                 [-3.7069171, 40.4302937] -3.706917
# 4           Point                 [-3.7025875, 40.4285524] -3.702587
# ..            ...                                      ...       ...
# 259         Point                     [-3.72699, 40.44375] -3.726990
# 260         Point                     [-3.72693, 40.44342] -3.726930
# 261         Point                 [-3.7272945, 40.4483322] -3.727295
# 262         Point                     [-3.72937, 40.45109] -3.729370
# 263         Point                     [-3.69281, 40.43837] -3.692810
#
#        LATITUD
# 0    40.417214
# 1    40.417313
# 2    40.420589
# 3    40.430294
# 4    40.428552
# ..         ...
# 259  40.443750
# 260  40.443420
# 261  40.448332
# 262  40.451090
# 263  40.438370
#
# [264 rows x 15 columns]
